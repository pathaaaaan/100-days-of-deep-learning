# %%
import seaborn as sns
iris = sns.load_dataset("iris")

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
# Scatter plot (Numerical - numerical)
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris)
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
sns.scatterplot(x="sepal_length", y="sepal_width", data=iris, hue="species")
# Out:
# <Axes: xlabel='sepal_length', ylabel='sepal_width'>

# %%
 # !pip install ydata_profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.6/8.6 MB 25.1 MB/s  0:00:00 eta 0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 45.0 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 35.6 MB/s  0:00:01m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 35.1 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 35.0 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.7/35.7 MB 35.7 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.3/10.3 MB 37.7 MB/s  0:00:00m0:00:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 38.2 MB/s  0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 554.9/554.9 kB 21.0 MB/s  0:00:00
# ...
#   Attempting uninstall: numpy━━━━━━━━━━━━━━━━━━━  0/18 [pytz]
#     Found existing installation: numpy 2.4.2━━━━━━━━━━━━━━━━━━━━━━  5/18 [numpy]
#     Uninstalling numpy-2.4.2:━━━━━━━━━━━━━━━━━━━━━━━━━━━━  5/18 [numpy]
# ...

# %%
import pandas as pd
from ydata_profiling import ProfileReport # Updated import

# Load your iris dataset (assuming it's a pandas DataFrame)
# iris = pd.read_csv("iris.csv") 

prof = ProfileReport(iris, title="Iris Data Profiling Report")
prof.to_file("iris.html") # 'to_file' is now the standard for saving
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[10], line 2
#       1 import pandas as pd
# ----> 2 from ydata_profiling import ProfileReport # Updated import
#       4 # Load your iris dataset (assuming it's a pandas DataFrame)
#       5 # iris = pd.read_csv("iris.csv")
#       7 prof = ProfileReport(iris, title="Iris Data Profiling Report")
#
# File /usr/local/python/3.12.1/lib/python3.12/site-packages/ydata_profiling/__init__.py:24
#      22 spec_numba = importlib.util.find_spec("numba")
#      23 if spec_numba is not None:
# ---> 24     from numba.core.errors import NumbaDeprecationWarning  # isort:skip # noqa
#      26     warnings.simplefilter("ignore", category=NumbaDeprecationWarning)
#      28 __all__ = [
#      29     "pandas_decorator",
#      30     "ProfileReport",
#      31     "__version__",
#      32     "compare",
#      33 ]
#
# ...
