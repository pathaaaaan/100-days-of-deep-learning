# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Steps
#
# ### 0. Preprocess + EDA + Feature Selection
#
# ### 1. Extract input and output cols
#
# ### 2. Scale the values
#
# ### 3. Train test split
#
# ### 4. Train the model
#
# ### 5. Evaluate the model/model selection
#
# ### 6. Deploy the model

# %%
df = pd.read_csv('/workspaces/100-days-of-deep-learning/datasets/placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 4 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  100 non-null    int64
#  1   cgpa        100 non-null    float64
#  2   iq          100 non-null    float64
#  3   placement   100 non-null    int64
# dtypes: float64(2), int64(2)
# memory usage: 3.3 KB

# %%
df.shape
# Out:
# (100, 4)

# %%
# df.iloc[0:5] gives you 5 rows (0, 1, 2, 3, 4).
#  It never includes the last number.
# iloc vs. loc: Use iloc for positions (numbers) and
#  loc for labels (names like "Age" or "City").

df = df.iloc[:, 1:]     # all rows, all columns except first one
df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 95   4.3  200.0          0
# 96   4.4   42.0          0
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [100 rows x 3 columns]

# %%
# visualization
import matplotlib.pyplot as plt

# %%
plt.scatter(df['cgpa'], df['iq'], c=df['placement'])

# %%
# input
x = df.iloc[:,0:2]
y = df.iloc[:,-1]

# %%
x
# Out:
#     cgpa     iq
# 0    6.8  123.0
# 1    5.9  106.0
# 2    5.3  121.0
# 3    7.4  132.0
# 4    5.8  142.0
# ..   ...    ...
# 95   4.3  200.0
# 96   4.4   42.0
# 97   6.7  182.0
# 98   6.3  103.0
# 99   6.2  113.0
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     0
# 3     1
# 4     0
#      ..
# 95    0
# 96    0
# 97    1
# 98    1
# 99    1
# Name: placement, Length: 100, dtype: int64

# %%
print(x.shape)
print(y.shape)
# Out:
# (100, 2)
# (100,)

# %%
# !pip install scikit-learn
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 22.9 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 38.7 MB/s  0:00:00m0:00:0100:01
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4/4 [scikit-learn] [scikit-learn]
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python3 -m pip install --upgrade pip

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, x_test, y_train, y_test =train_test_split(x, y, test_size=0.1, random_state=42)

# %%
X_train
# Out:
#     cgpa     iq
# 18   4.0  100.0
# 30   7.6  128.0
# 73   4.9   61.0
# 33   6.0  149.0
# 90   7.3   86.0
# ..   ...    ...
# 60   6.9  139.0
# 71   6.1  132.0
# 14   6.1  103.0
# 92   5.2  110.0
# 51   4.8  141.0
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 18    0
# 30    1
# 73    0
# 33    0
# 90    1
#      ..
# 60    1
# 71    1
# 14    0
# 92    0
# 51    0
# Name: placement, Length: 90, dtype: int64

# %% [markdown]
# ### scaling

# %%
from sklearn.preprocessing import StandardScaler
scalar = StandardScaler()
X_train = scalar.fit_transform(X_train)

# %%
x_test = scalar.transform(x_test)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()

# %% [markdown]
# ### Model Training

# %%
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %% [markdown]
# ## Model Evaluation

# %%
y_pred = model.predict(x_test)

# %%
results
# Out:
# array([1, 1, 1, 0, 1, 0, 0, 0, 0, 1])

# %%
y_test
# Out:
# 83    1
# 53    1
# 70    1
# 45    1
# 44    1
# 39    0
# 22    0
# 80    0
# 10    1
# 0     1
# Name: placement, dtype: int64

# %%
from sklearn.metrics import accuracy_score
accuracy = accuracy_score(y_test, results)

# %%
print(f"Accuracy : {accuracy*100}%")
# Out:
# Accuracy : 80.0%

# %% [markdown]
# ### plotting the decision boundary

# %%
# %pip install mlxtend
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 8.2 MB/s  0:00:00 eta 0:00:01
# ...
#
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.plotting import plot_decision_regions

# %%
plot_decision_regions(X_train, y_train.values, clf = model, legend=2)
# Out:
# <Axes: >
